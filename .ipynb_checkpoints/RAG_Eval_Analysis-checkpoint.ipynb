# %% [markdown]
# # RAG Evaluation Analysis Notebook
#
# This notebook loads `rag_eval_results.jsonl` produced by `app/eval_rag.py`,
# builds per-category summaries, and renders **box plots per category** for each metric.
#
# ## What you'll get
# - A tidy DataFrame of all evaluation records
# - Summary stats per category
# - Box plots per category for each metric
# - Optional bar charts of mean values per category
#
# ## Metrics (from eval script)
# - `qa_cosine`: alignment between question and answer embeddings (higher = better)
# - `q_ctx_cosine`: alignment between question and retrieved context (higher = better)
# - `a_ctx_cosine`: alignment between answer and retrieved context (higher = better)
# - `jaccard_q_ctx`: lexical overlap between question and context (higher typically better)
# - `jaccard_a_ctx`: lexical overlap between answer and context (moderate is OK; very low may indicate hallucination)
# - `rougeL_recall_a_ctx`: ROUGE-L recall of answer vs context (higher = better grounding)
# - `answer_novelty_vs_ctx`: fraction of answer tokens absent from context (lower = better grounding)
# - `response_length`, `within_char_cap`: response control metrics
#
# ## Interpretation cheat sheet
# - **Grounding** → prioritize `a_ctx_cosine`, `rougeL_recall_a_ctx`, *low* `answer_novelty_vs_ctx`
# - **Retrieval quality** → `q_ctx_cosine`, `jaccard_q_ctx`
# - **Answer relevance** → `qa_cosine`, `jaccard_a_ctx`
# - **Brevity control** → `within_char_cap` and `response_length`

# %%
# # Fallback display helper for local Jupyter
# try:
#     from caas_jupyter_tools import display_dataframe_to_user  # not available locally
# except ImportError:
#     from IPython.display import display

#     def display_dataframe_to_user(name: str, dataframe):
#         # simple local replacement
#         try:
#             print(f"== {name} ==")
#         except Exception:
#             pass
#         display(dataframe)

# %%
from IPython.display import display

# %%
# ----- Setup -----
from pathlib import Path
import json
import pandas as pd
import matplotlib.pyplot as plt
# from caas_jupyter_tools import display_dataframe_to_user



# Path to your JSONL results (edit if needed)
RESULTS_PATH = Path('rag_eval_results.jsonl')

# Metrics to analyze
METRICS = [
    'qa_cosine', 'q_ctx_cosine', 'a_ctx_cosine',
    'jaccard_q_ctx', 'jaccard_a_ctx',
    'rougeL_recall_a_ctx', 'answer_novelty_vs_ctx'
]

assert RESULTS_PATH.exists(), f"Results file not found: {RESULTS_PATH}"

records = []
summary = None
with RESULTS_PATH.open('r', encoding='utf-8') as f:
    for line in f:
        line = line.strip()
        if not line:
            continue
        obj = json.loads(line)
        if 'summary' in obj:
            summary = obj['summary']
            continue
        records.append(obj)

df = pd.json_normalize(records)
print(f"Loaded {len(df)} records.")
if summary is not None:
    print('Run summary:', summary)
    
print('RAG Eval Records')
display(df)
# display_dataframe_to_user('', df)
df.head()
# Out:
# Loaded 60 records.
# Run summary: {'n': 60, 'avg_qa_cosine': 0.4378, 'avg_q_ctx_cosine': 0.3628, 'avg_a_ctx_cosine': 0.5219, 'avg_jaccard_q_ctx': 0.0119, 'avg_jaccard_a_ctx': 0.0697, 'avg_rougeL_recall_a_ctx': 0.8472, 'avg_answer_novelty': 0.151, 'pct_within_char_cap': 100.0, 'avg_response_length': 105.0}
# RAG Eval Records
#      id                  category  \
# 0    A1                fact_check
# 1    A2                fact_check
# 2    A3                fact_check
# 3    A4                fact_check
# 4    A5                fact_check
# 5    A6                fact_check
# 6    A7                fact_check
# 7    A8                fact_check
# 8    A9                fact_check
# 9   A10                fact_check
# 10   B1             summarization
# 11   B2             summarization
# 12   B3             summarization
# 13   B4             summarization
# 14   B5             summarization
# 15   B6             summarization
# 16   B7             summarization
# 17   B8             summarization
# 18   B9             summarization
# 19  B10             summarization
# 20   C1             noisy_grammar
# 21   C2             noisy_grammar
# 22   C3             noisy_grammar
# 23   C4             noisy_grammar
# 24   C5             noisy_grammar
# 25   C6             noisy_grammar
# 26   C7             noisy_grammar
# 27   C8             noisy_grammar
# 28   C9             noisy_grammar
# 29  C10             noisy_grammar
# 30   D1              multilingual
# 31   D2              multilingual
# 32   D3              multilingual
# 33   D4              multilingual
# 34   D5              multilingual
# 35   D6              multilingual
# 36   D7              multilingual
# 37   D8              multilingual
# 38   D9              multilingual
# 39  D10              multilingual
# 40   E1       semantic_paraphrase
# 41   E2       semantic_paraphrase
# 42   E3       semantic_paraphrase
# 43   E4       semantic_paraphrase
# 44   E5       semantic_paraphrase
# 45   E6       semantic_paraphrase
# 46   E7       semantic_paraphrase
# 47   E8       semantic_paraphrase
# 48   E9       semantic_paraphrase
# 49  E10       semantic_paraphrase
# 50   F1  on_topic_outside_context
# 51   F2  on_topic_outside_context
# 52   F3  on_topic_outside_context
# 53   F4  on_topic_outside_context
# 54   F5  on_topic_outside_context
# 55   F6  on_topic_outside_context
# 56   F7  on_topic_outside_context
# 57   F8  on_topic_outside_context
# 58   F9  on_topic_outside_context
# 59  F10  on_topic_outside_context
#
#                                                 query  \
# 0   What is the recommended age to start complemen...
# 1   How long should exclusive breastfeeding continue?
# 2        When should breastfeeding begin after birth?
# 3   Until what age should breastfeeding continue a...
# 4   Should infants be given water in the first 6 m...
# 5   How often should infants be breastfed (on dema...
# 6   Does WHO advise avoiding bottles and pacifiers...
# 7   Which organization recommends exclusive breast...
# 8   Does WHO recommend continued breastfeeding up ...
# 9   Does exclusive breastfeeding include no water ...
# 10  Summarize the key WHO recommendations for infa...
# 11  Give a one-sentence summary of optimal infant ...
# 12  Briefly state the three pillars: early initiat...
# 13  Summarize WHO guidance on when to add compleme...
# 14  In one line, what is WHO policy on exclusive b...
# 15  Summarize WHO's stance on bottle feeding and p...
# 16  Provide a short summary of on-demand feeding f...
# 17  Summarize WHO guidance for feeding infants und...
# 18  Summarize complementary feeding timing and con...
# 19  Give a concise overview of WHO recommendations...
# 20  When should start two feeding complementary fo...
# 21  Exclusive breastfeed at six month is recommended?
# 22  Is breastfeeding should started within birth o...
# 23  Complementary feeding begins 6 month with brea...
# 24  Water can given in exclusive feeding first six...
# 25    Breastfeeding beyond two year is WHO recommend?
# 26                  Should pacifiers not used babies?
# 27  Solid introduced at six months with breastfeed...
# 28  Exclusive breastfeeding means no water or soli...
# 29  Breastfeed on demand meaning frequent day and ...
# 30  ¿Cuándo se deben introducir los alimentos comp...
# 31  Quel est l’âge recommandé pour commencer l’all...
# 32                                根据世卫组织，母乳喂养应持续多长时间？
# 33      Wann sollten feste Nahrung eingeführt werden?
# 34  Quando iniziare i cibi complementari secondo l...
# 35  Should complementary food start at 6 months ac...
# 36  ¿La OMS recomienda lactancia exclusiva hasta l...
# 37  ¿Debe iniciarse la lactancia dentro de la prim...
# 38                                  辅食应与母乳一起持续到2岁以上吗？
# 39     ¿La OMS recomienda evitar el uso de biberones?
# 40  At what age do health agencies advise beginnin...
# 41      How soon after birth should nursing commence?
# 42  Should infants stop breastfeeding before addin...
# 43  Does WHO support overlapping breast milk with ...
# 44  What is the guidance on pacifier use for early...
# 45  Is giving water allowed during the first six m...
# 46  When does exclusive breastfeeding end per glob...
# 47  What combination of foods does WHO recommend a...
# 48   How does WHO view feeding on demand for infants?
# 49  Is bottle feeding recommended for newborns per...
# 50  Should exclusively breastfed infants receive v...
# 51  Is it acceptable to introduce formula before s...
# 52  What are signs of dehydration in exclusively b...
# 53     Should infants consume honey before 12 months?
# 54                     Is microwaving baby food safe?
# 55    How should pumped breast milk be stored safely?
# 56  What vaccines are recommended at 2 months of age?
# 57         How much water should infants drink daily?
# 58  Are plant-based milk alternatives appropriate ...
# 59  How much breast milk does a 3-month-old typica...
#
#                                                answer  response_length  \
# 0                                                   a                1
# 1                                         a few years               11
# 2   4 August 2025 Breastfeeding in Indonesia on th...              130
# 3                            2 years of age or beyond               24
# 4   Breastfeeding in Indonesia on the rise, but mo...              137
# 5   Continue frequent, on-demand breastfeeding unt...              139
# 6   More on breastfeedingMore about infant nutriti...              135
# 7   World Breastfeeding Week, countries urged to i...              135
# 8   Guiding principles for appropriate complementa...              136
# 9   exclusive and continued breastfeeding can be i...              119
# 10  Related Global Strategy for Infant and Young C...              130
# 11  Related Global Strategy for Infant and Young C...              130
# 12        early initiation, exclusivity, and duration               43
# 13  Related Global Strategy for Infant and Young C...              130
# 14  The prevalence of exclusive and continued brea...              103
# 15  Related Global Strategy for Infant and Young C...              130
# 16  Related Global Strategy for Infant and Young C...              130
# 17  Guiding principles for appropriate complementa...              136
# 18  Complementary feedingAround the age of 6 month...              135
# 19  World Health Statistics UHC global monitoring ...              139
# 20                                       Around the a               12
# 21  Complementary feedingAround the age of 6 month...              135
# 22  --- Surveillance Alert and response Operations...              131
# 23                           2 years of age or beyond               24
# 24  Complementary feedingAround the age of 6 month...              135
# 25  Guiding principles for appropriate complementa...              136
# 26  Breastfeeding in Indonesia on the rise, but mo...              137
# 27  Complementary feedingAround the age of 6 month...              135
# 28  exclusive and continued breastfeeding can be i...               85
# 29  Breastfeeding in Indonesia on the rise, but mo...              137
# 30  1 August 2025 Breastfeeding in Indonesia on th...              130
# 31  Infant and Young Child FeedingMore on breastfe...              126
# 32                                                 ,?                2
# 33  World Breastfeeding Week, countries urged to i...              135
# 34  Surveillance Alert and response Operations Res...              139
# 35  Complementary feedingAround the age of 6 month...              135
# 36  La OMS recomienda lactancia exclusiva hasta lo...               59
# 37  Surveillance Alert and response Operations Res...              139
# 38  Surveillance Alert and response Operations Res...              139
# 39  Surveillance Alert and response Operations Res...              139
# 40                                                  a                1
# 41                                      1 August 2025               13
# 42  Complementary feedingAround the age of 6 month...              135
# 43  Guiding principles for appropriate complementa...              135
# 44  Related Global Strategy for Infant and Young C...              130
# 45  Is giving water allowed during the first six m...               52
# 29  Related\nGlobal Strategy for Infant and Young ...           0.432002
# 30  Surveillance\n\n\nAlert and response\n\n\nOper...          -0.023317
# 31  Surveillance\n\n\nAlert and response\n\n\nOper...           0.087687
# 32  Surveillance\n\n\nAlert and response\n\n\nOper...           0.044214
# 33  Surveillance\n\n\nAlert and response\n\n\nOper...           0.004764
# 34  Surveillance\n\n\nAlert and response\n\n\nOper...          -0.007027
# 35  Related\nGlobal Strategy for Infant and Young ...           0.627549
# 36  Surveillance\n\n\nAlert and response\n\n\nOper...           0.972114
# 37  Surveillance\n\n\nAlert and response\n\n\nOper...           0.015458
# 38  Surveillance\n\n\nAlert and response\n\n\nOper...          -0.065267
# 39  Surveillance\n\n\nAlert and response\n\n\nOper...           0.059734
# 40  Related\nGlobal Strategy for Infant and Young ...          -0.058034
# 41  Related\nGlobal Strategy for Infant and Young ...           0.197177
# 42  Related\nGlobal Strategy for Infant and Young ...           0.623740
# 43  Related\nGlobal Strategy for Infant and Young ...           0.558757
# 44  Related\nGlobal Strategy for Infant and Young ...           0.603062
# 45  Related\nGlobal Strategy for Infant and Young ...           1.000000
# 46  Related\nGlobal Strategy for Infant and Young ...           0.283449
# 47  Related\nGlobal Strategy for Infant and Young ...           0.209715
# 48  Related\nGlobal Strategy for Infant and Young ...           0.479606
# 49  Related\nGlobal Strategy for Infant and Young ...           1.000000
# 50  Related\nGlobal Strategy for Infant and Young ...           0.307826
# 51  Related\nGlobal Strategy for Infant and Young ...           1.000000
# 52  Related\nGlobal Strategy for Infant and Young ...           0.183361
# 53  Related\nGlobal Strategy for Infant and Young ...           0.311035
# 54  Surveillance\n\n\nAlert and response\n\n\nOper...           0.817781
# 55  Related\nGlobal Strategy for Infant and Young ...           0.262247
# 56  Surveillance\n\n\nAlert and response\n\n\nOper...           0.376608
# 57  Surveillance\n\n\nAlert and response\n\n\nOper...           0.334303
# 58  Related\nGlobal Strategy for Infant and Young ...           1.000000
# 59  Related\nGlobal Strategy for Infant and Young ...           0.572098
#
#     metrics.q_ctx_cosine  metrics.a_ctx_cosine  metrics.jaccard_q_ctx  \
# 0               0.264040              0.013488               0.016667
# 1               0.533804              0.023380               0.009950
# 2               0.427379              0.713858               0.005587
# 3               0.631845              0.171581               0.025641
# 4               0.274041              0.795477               0.016575
# 5               0.493569              0.659679               0.010000
# 6               0.378424              0.750799               0.016667
# 7               0.649702              0.724771               0.020513
# 8               0.579421              0.691075               0.029703
# 9               0.410669              0.569232               0.016760
# 10              0.556012              0.686081               0.022472
# 11              0.418835              0.678505               0.021739
# 12              0.106610              0.053962               0.016216
# 13              0.458487              0.686081               0.032967
# 14              0.595658              0.617995               0.022222
# 15              0.453989              0.686081               0.016575
# 16              0.504768              0.686081               0.016667
# 17              0.529942              0.691075               0.020408
# 18              0.603873              0.689089               0.019900
# 19              0.266043              0.545721               0.023810
# 20              0.318058             -0.065631               0.005556
# 21              0.555321              0.689089               0.010204
# 22              0.417306              0.222919               0.010152
# 23              0.657117              0.171581               0.020408
# 24              0.431265              0.689089               0.025641
# 25              0.592066              0.691075               0.014925
# 58               0.015385                     0.428571
# 59               0.109375                     0.954545
#
#     metrics.answer_novelty_vs_ctx
# 0                        0.000000
# 1                        0.000000
# 2                        0.045455
# 3                        0.166667
# 4                        0.047619
# 5                        0.105263
# 6                        0.062500
# 7                        0.052632
# 8                        0.058824
# 9                        0.000000
# 10                       0.066667
# 11                       0.066667
# 12                       0.600000
# 13                       0.066667
# 14                       0.000000
# 15                       0.066667
# 16                       0.066667
# 17                       0.058824
# 18                       0.045455
# 19                       0.055556
# 20                       0.333333
# 21                       0.045455
# 22                       0.066667
# 23                       0.166667
# 24                       0.045455
# 25                       0.058824
# 26                       0.047619
# 27                       0.045455
# 28                       0.000000
# 29                       0.047619
# 30                       0.045455
# 31                       0.066667
# 32                       1.000000
# 33                       0.052632
# 34                       0.066667
# 35                       0.045455
# 36                       1.000000
# 37                       0.066667
# 38                       0.066667
# 39                       0.066667
# 40                       0.000000
# 41                       0.000000
# 42                       0.045455
# 43                       0.000000
# 44                       0.066667
# 45                       0.888889
# 46                       0.000000
# 47                       0.047619
# 48                       0.052632
# 49                       0.875000
# 50                       0.047619
# 51                       0.909091
# 52                       0.062500
# 53                       0.058824
# 54                       0.230769
# 55                       0.047619
# 56                       0.076923
# 57                       0.066667
# 58                       0.571429
# 59                       0.045455
#    id    category                                              query  \
# 0  A1  fact_check  What is the recommended age to start complemen...
# 1  A2  fact_check  How long should exclusive breastfeeding continue?
# 2  A3  fact_check       When should breastfeeding begin after birth?
# 3  A4  fact_check  Until what age should breastfeeding continue a...
# 4  A5  fact_check  Should infants be given water in the first 6 m...
#
#                                               answer  response_length  \
# 0                                                  a                1
# 1                                        a few years               11
# 2  4 August 2025 Breastfeeding in Indonesia on th...              130
# 3                           2 years of age or beyond               24
# 4  Breastfeeding in Indonesia on the rise, but mo...              137
#
#    within_char_cap                                            sources  \
# 0             True  [https://www.who.int/news-room/fact-sheets/det...
# 1             True  [https://www.who.int/news-room/fact-sheets/det...
# 2             True  [https://www.who.int/news-room/fact-sheets/det...
# 3             True  [https://www.who.int/news-room/fact-sheets/det...
# 4             True  [https://www.who.int/news-room/fact-sheets/det...
#
#                                    retrieved_sources  \
# 0  [https://www.who.int/news-room/fact-sheets/det...
# 1  [https://www.who.int/news-room/fact-sheets/det...
# 2  [https://www.who.int/news-room/fact-sheets/det...
# 3  [https://www.who.int/news-room/fact-sheets/det...
# 4  [https://www.who.int/news-room/fact-sheets/det...
#
#                                              context  metrics.qa_cosine  \
# 0  Related\nGlobal Strategy for Infant and Young ...          -0.007307
# 1  Related\nGlobal Strategy for Infant and Young ...           0.236783
# 2  Related\nGlobal Strategy for Infant and Young ...           0.441865
# 3  Related\nGlobal Strategy for Infant and Young ...           0.398183
# 4  Related\nGlobal Strategy for Infant and Young ...           0.284887
#
#    metrics.q_ctx_cosine  metrics.a_ctx_cosine  metrics.jaccard_q_ctx  \
# 0              0.264040              0.013488               0.016667
# 1              0.533804              0.023380               0.009950
# 2              0.427379              0.713858               0.005587
# 3              0.631845              0.171581               0.025641
# 4              0.274041              0.795477               0.016575
#
#    metrics.jaccard_a_ctx  metrics.rougeL_recall_a_ctx  \
# 0               0.005747                     1.000000
# 1               0.015228                     1.000000
# 2               0.108571                     0.954545
# 3               0.026042                     0.833333
# 4               0.114286                     0.952381
#
#    metrics.answer_novelty_vs_ctx
# 0                       0.000000
# 1                       0.000000
# 2                       0.045455
# 3                       0.166667
# 4                       0.047619

# %%
# ----- Basic cleanliness checks -----
required_cols = ['category', 'query', 'answer', 'metrics.qa_cosine']
missing = [c for c in required_cols if c not in df.columns]
if missing:
    raise ValueError(f"Missing columns in results: {missing}")

# Short aliases for metric columns
for m in ['qa_cosine','q_ctx_cosine','a_ctx_cosine','jaccard_q_ctx','jaccard_a_ctx','rougeL_recall_a_ctx','answer_novelty_vs_ctx']:
    col = f'metrics.{m}'
    if col in df.columns:
        df[m] = df[col]
    else:
        df[m] = None

# Make sure 'category' exists
if 'category' not in df.columns:
    df['category'] = 'unknown'

df_metrics = df[['id','category','response_length','within_char_cap'] + METRICS].copy()
# display_dataframe_to_user('RAG Eval Metrics (wide)', df_metrics)
print('RAG Eval Metrics (wide)')
display(df_metrics)
df_metrics.head()
# Out:
# RAG Eval Metrics (wide)
#      id                  category  response_length  within_char_cap  \
# 0    A1                fact_check                1             True
# 1    A2                fact_check               11             True
# 2    A3                fact_check              130             True
# 3    A4                fact_check               24             True
# 4    A5                fact_check              137             True
# 5    A6                fact_check              139             True
# 6    A7                fact_check              135             True
# 7    A8                fact_check              135             True
# 8    A9                fact_check              136             True
# 9   A10                fact_check              119             True
# 10   B1             summarization              130             True
# 11   B2             summarization              130             True
# 12   B3             summarization               43             True
# 13   B4             summarization              130             True
# 14   B5             summarization              103             True
# 15   B6             summarization              130             True
# 16   B7             summarization              130             True
# 17   B8             summarization              136             True
# 18   B9             summarization              135             True
# 19  B10             summarization              139             True
# 20   C1             noisy_grammar               12             True
# 21   C2             noisy_grammar              135             True
# 22   C3             noisy_grammar              131             True
# 23   C4             noisy_grammar               24             True
# 24   C5             noisy_grammar              135             True
# 25   C6             noisy_grammar              136             True
# 26   C7             noisy_grammar              137             True
# 27   C8             noisy_grammar              135             True
# 28   C9             noisy_grammar               85             True
# 29  C10             noisy_grammar              137             True
# 30   D1              multilingual              130             True
# 31   D2              multilingual              126             True
# 32   D3              multilingual                2             True
# 33   D4              multilingual              135             True
# 34   D5              multilingual              139             True
# 35   D6              multilingual              135             True
# 36   D7              multilingual               59             True
# 37   D8              multilingual              139             True
# 38   D9              multilingual              139             True
# 39  D10              multilingual              139             True
# 40   E1       semantic_paraphrase                1             True
# 41   E2       semantic_paraphrase               13             True
# 42   E3       semantic_paraphrase              135             True
# 43   E4       semantic_paraphrase              135             True
# 44   E5       semantic_paraphrase              130             True
# 45   E6       semantic_paraphrase               52             True
# 46   E7       semantic_paraphrase               13             True
# 47   E8       semantic_paraphrase              137             True
# 48   E9       semantic_paraphrase              135             True
# 49  E10       semantic_paraphrase               51             True
# 50   F1  on_topic_outside_context              137             True
# 51   F2  on_topic_outside_context               66             True
# 52   F3  on_topic_outside_context              133             True
# 53   F4  on_topic_outside_context              132             True
# 4      0.795477       0.016575       0.114286             0.952381
#
#    answer_novelty_vs_ctx
# 0               0.000000
# 1               0.000000
# 2               0.045455
# 3               0.166667
# 4               0.047619

# %%
# ----- Summary by category -----
summary_cols = ['response_length'] + METRICS
summary_by_cat = df_metrics.groupby('category')[summary_cols].agg(['count','mean','std']).round(4)
# from caas_jupyter_tools import display_dataframe_to_user
# display_dataframe_to_user('Summary by Category (count/mean/std)', summary_by_cat)
print('Summary by Category (count/mean/std)')
display(summary_by_cat)
summary_by_cat
# Out:
# Summary by Category (count/mean/std)
#                          response_length                 qa_cosine          \
#                                    count   mean      std     count    mean
# category
# fact_check                            10   96.7  58.9596        10  0.4333
# multilingual                          10  114.3  46.3682        10  0.1716
# noisy_grammar                         10  106.7  49.4032        10  0.4068
# on_topic_outside_context              10  111.2  32.8965        10  0.5165
# semantic_paraphrase                   10   80.2  59.3180        10  0.4897
# summarization                         10  120.6  28.9759        10  0.6088
#
#                                  q_ctx_cosine                 a_ctx_cosine  \
#                              std        count    mean     std        count
# category
# fact_check                0.2156           10  0.4643  0.1372           10
# multilingual              0.3436           10  0.1127  0.1507           10
# noisy_grammar             0.2483           10  0.4680  0.1117           10
# on_topic_outside_context  0.3119           10  0.2635  0.1248           10
# semantic_paraphrase       0.3437           10  0.4190  0.1290           10
# summarization             0.1386           10  0.4494  0.1558           10
#
#                           ... jaccard_q_ctx jaccard_a_ctx                  \
#                           ...           std         count    mean     std
# category                  ...
# fact_check                ...        0.0073            10  0.0694  0.0390
# multilingual              ...        0.0048            10  0.0683  0.0383
# noisy_grammar             ...        0.0076            10  0.0816  0.0376
# on_topic_outside_context  ...        0.0066            10  0.0712  0.0385
# semantic_paraphrase       ...        0.0087            10  0.0528  0.0463
# summarization             ...        0.0049            10  0.0748  0.0248
#
#                          rougeL_recall_a_ctx                  \
#                                        count    mean     std
# category
# fact_check                                10  0.9399  0.0566
# multilingual                              10  0.7478  0.3943
# noisy_grammar                             10  0.9143  0.0966
# on_topic_outside_context                  10  0.7883  0.2949
# semantic_paraphrase                       10  0.8024  0.3616
# summarization                             10  0.8907  0.1736
#
#                          answer_novelty_vs_ctx
#                                          count    mean     std
# category
# fact_check                                  10  0.0539  0.0519
# multilingual                                10  0.2477  0.3966
# noisy_grammar                               10  0.0857  0.0966
# on_topic_outside_context                    10  0.2117  0.2949
# semantic_paraphrase                         10  0.1976  0.3616
# summarization                               10  0.1093  0.1736
#
# [6 rows x 24 columns]
#                          response_length                 qa_cosine          \
#                                    count   mean      std     count    mean
# category
# fact_check                            10   96.7  58.9596        10  0.4333
# multilingual                          10  114.3  46.3682        10  0.1716
# noisy_grammar                         10  106.7  49.4032        10  0.4068
# on_topic_outside_context              10  111.2  32.8965        10  0.5165
# semantic_paraphrase                   10   80.2  59.3180        10  0.4897
# summarization                         10  120.6  28.9759        10  0.6088
#
#                                  q_ctx_cosine                 a_ctx_cosine  \
#                              std        count    mean     std        count
# category
# fact_check                0.2156           10  0.4643  0.1372           10
# multilingual              0.3436           10  0.1127  0.1507           10
# noisy_grammar             0.2483           10  0.4680  0.1117           10
# on_topic_outside_context  0.3119           10  0.2635  0.1248           10
# semantic_paraphrase       0.3437           10  0.4190  0.1290           10
# summarization             0.1386           10  0.4494  0.1558           10
#
#                           ... jaccard_q_ctx jaccard_a_ctx                  \
#                           ...           std         count    mean     std
# category                  ...
# fact_check                ...        0.0073            10  0.0694  0.0390
# multilingual              ...        0.0048            10  0.0683  0.0383
# noisy_grammar             ...        0.0076            10  0.0816  0.0376
# on_topic_outside_context  ...        0.0066            10  0.0712  0.0385
# semantic_paraphrase       ...        0.0087            10  0.0528  0.0463
# summarization             ...        0.0049            10  0.0748  0.0248
#
#                          rougeL_recall_a_ctx                  \
#                                        count    mean     std
# category
# fact_check                                10  0.9399  0.0566
# multilingual                              10  0.7478  0.3943
# noisy_grammar                             10  0.9143  0.0966
# on_topic_outside_context                  10  0.7883  0.2949
# semantic_paraphrase                       10  0.8024  0.3616
# summarization                             10  0.8907  0.1736
#
#                          answer_novelty_vs_ctx
#                                          count    mean     std
# category
# fact_check                                  10  0.0539  0.0519
# multilingual                                10  0.2477  0.3966
# noisy_grammar                               10  0.0857  0.0966
# on_topic_outside_context                    10  0.2117  0.2949
# semantic_paraphrase                         10  0.1976  0.3616
# summarization                               10  0.1093  0.1736
#
# [6 rows x 24 columns]

# %% [markdown]
# ## Box plots per metric (by category)
# Each plot shows the distribution of a metric across categories. This helps identify variance, outliers, and skew.

# %%
# ----- Box plots for each metric -----
import os
plots_dir = Path('plots')
plots_dir.mkdir(exist_ok=True)

cats = list(df_metrics['category'].dropna().unique())
cats.sort()
for m in METRICS:
    plt.figure()
    data = [df_metrics[df_metrics['category']==c][m].dropna().values for c in cats]
    plt.boxplot(data, labels=cats, showfliers=True)
    plt.title(f'Box plot of {m} by category')
    plt.ylabel(m)
    plt.xticks(rotation=30, ha='right')
    out_path = plots_dir / f'box_{m}.png'
    plt.tight_layout()
    plt.savefig(out_path)
    plt.show()
    print(f'Saved {out_path}')
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_32064\1054725135.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=cats, showfliers=True)
# Saved plots\box_qa_cosine.png
# C:\Users\User\AppData\Local\Temp\ipykernel_32064\1054725135.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=cats, showfliers=True)
# Saved plots\box_q_ctx_cosine.png
# C:\Users\User\AppData\Local\Temp\ipykernel_32064\1054725135.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=cats, showfliers=True)
# Saved plots\box_a_ctx_cosine.png
# C:\Users\User\AppData\Local\Temp\ipykernel_32064\1054725135.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=cats, showfliers=True)
# C:\Users\User\AppData\Local\Temp\ipykernel_32064\1054725135.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=cats, showfliers=True)
# Saved plots\box_jaccard_q_ctx.png
# Saved plots\box_jaccard_a_ctx.png
# C:\Users\User\AppData\Local\Temp\ipykernel_32064\1054725135.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=cats, showfliers=True)
# Saved plots\box_rougeL_recall_a_ctx.png
# C:\Users\User\AppData\Local\Temp\ipykernel_32064\1054725135.py:11: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=cats, showfliers=True)
# Saved plots\box_answer_novelty_vs_ctx.png

# %% [markdown]
# ## Median comparison bar charts (by category)
# These complement box plots by summarizing central tendency per category.

# %%
# ----- Median bar charts for each metric -----
medians = df_metrics.groupby('category')[METRICS].median().reset_index()

print('Metric Medians by Category')
display(medians)

for m in METRICS:
    plt.figure()
    x = medians['category']
    y = medians[m]
    plt.bar(x, y)
    plt.title(f'Median {m} by category')
    plt.ylabel(m)
    plt.xticks(rotation=30, ha='right')
    out_path = Path('plots') / f'median_{m}.png'
    plt.tight_layout()
    plt.savefig(out_path)
    plt.show()
    print(f'Saved {out_path}')

# %% [markdown]
# ## Mean comparison bar charts (by category)
# These complement box plots by summarizing central tendency per category.

# %%
# ----- Mean bar charts for each metric -----
means = df_metrics.groupby('category')[METRICS].mean().reset_index()
# from caas_jupyter_tools import display_dataframe_to_user
# display_dataframe_to_user('Metric Means by Category', means)

print('Metric Means by Category')
display(means)

for m in METRICS:
    plt.figure()
    x = means['category']
    y = means[m]
    plt.bar(x, y)
    plt.title(f'Mean {m} by category')
    plt.ylabel(m)
    plt.xticks(rotation=30, ha='right')
    out_path = Path('plots') / f'mean_{m}.png'
    plt.tight_layout()
    plt.savefig(out_path)
    plt.show()
    print(f'Saved {out_path}')
# Out:
# Metric Means by Category
#                    category  qa_cosine  q_ctx_cosine  a_ctx_cosine  \
# 0                fact_check   0.433304      0.464289      0.511334
# 1              multilingual   0.171591      0.112729      0.494715
# 2             noisy_grammar   0.406802      0.467978      0.530381
# 3  on_topic_outside_context   0.516526      0.263511      0.548145
# 4       semantic_paraphrase   0.489747      0.418970      0.444565
# 5             summarization   0.608810      0.449422      0.602067
#
#    jaccard_q_ctx  jaccard_a_ctx  rougeL_recall_a_ctx  answer_novelty_vs_ctx
# 0       0.016806       0.069405             0.939854               0.053896
# 1       0.001515       0.068317             0.747767               0.247687
# 2       0.011835       0.081598             0.914291               0.085709
# 3       0.007469       0.071241             0.788311               0.211689
# 4       0.012411       0.052759             0.802374               0.197626
# 5       0.021298       0.074788             0.890683               0.109317
# Saved plots\mean_qa_cosine.png
# Saved plots\mean_q_ctx_cosine.png
# Saved plots\mean_a_ctx_cosine.png
# Saved plots\mean_jaccard_q_ctx.png
# Saved plots\mean_jaccard_a_ctx.png
# Saved plots\mean_rougeL_recall_a_ctx.png
# Saved plots\mean_answer_novelty_vs_ctx.png

# %% [markdown]
# ## Interpreting the results
# - **`a_ctx_cosine`**: If consistently high across categories, answers are well grounded in retrieved context. If low for a category (e.g., multilingual), consider improving multilingual retrieval/translation.
# - **`q_ctx_cosine`**: Indicates retriever is pulling relevant chunks. If low for noisy grammar or paraphrased queries, consider query normalization or better embeddings.
# - **`qa_cosine`**: High suggests answers are relevant to the question. If this is high but `a_ctx_cosine` is low, answers may be relevant but not grounded → improve RAG grounding.
# - **`rougeL_recall_a_ctx`**: High values (e.g., >0.7) mean the answer reuses content from context, a good proxy for grounding.
# - **`answer_novelty_vs_ctx`**: Lower is better; if high, the model is adding content not present in context (risk of hallucination).
# - **`jaccard_*`**: Helpful lexical sanity checks; very low `jaccard_a_ctx` plus low `a_ctx_cosine` is a red flag.
# - **`response_length` & `within_char_cap`**: Ensure formatting constraints are met; if length is near the cap across the board, consider reducing `MAX_CHAR_LEN_RESP` or enforcing stricter brevity.
#
# ### What conclusions to draw
# 1. **Compare categories**: Identify which categories underperform (e.g., `multilingual`, `noisy_grammar`) and target improvements (translation layer, spelling correction, better retrieval).
# 2. **Retrieval vs. Generation**: If `q_ctx_cosine` is strong but `a_ctx_cosine` is weak, focus on the prompt to force grounding; if `q_ctx_cosine` is weak, focus on embeddings, chunking, or sources.
# 3. **Precision vs. Recall**: High `rougeL_recall_a_ctx` with low `qa_cosine` might indicate copying context without addressing the question; tune templates.
# 4. **Safety/Brevity**: Ensure `within_char_cap` is 100%. If not, tighten the post-processor or reduce `MAX_CHAR_LEN_RESP`.
